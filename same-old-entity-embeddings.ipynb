# %% [markdown]
# #  Categorical Feature Encoding Challenge II V1

# %%
import warnings
warnings.filterwarnings("ignore")


import os
import gc
import joblib
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import StratifiedKFold
from sklearn import metrics, preprocessing
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from tensorflow.keras.models import Model, load_model
from tensorflow.keras import callbacks
from tensorflow.keras import backend as K
from tensorflow.keras import utils

pd.set_option("display.max_columns", 100)

# %%
def auc(y_true, y_pred):
    def fallback_auc(y_true, y_pred):
        try:
            return metrics.roc_auc_score(y_true, y_pred)
        except:
            return 0.5
    return tf.py_function(fallback_auc, (y_true, y_pred), tf.double)

# %%
def create_model(data, catcols):    
    inputs = []
    outputs = []
    for c in catcols:
        num_unique_values = int(data[c].nunique())
        embed_dim = int(min(np.ceil((num_unique_values)/2), 100))
        inp = layers.Input(shape=(1,))
        out = layers.Embedding(num_unique_values + 1, embed_dim, name=c)(inp)
        out = layers.SpatialDropout1D(0.25)(out)
        out = layers.Reshape(target_shape=(embed_dim, ))(out)
        inputs.append(inp)
        outputs.append(out)
    
    x = layers.Concatenate()(outputs)
    x = layers.BatchNormalization()(x)
    
    x = layers.Dense(500, activation="relu")(x)
    x = layers.Dropout(0.25)(x)
    x = layers.BatchNormalization()(x)
        
    x = layers.Dense(500, activation="relu")(x)
    x = layers.Dropout(0.25)(x)
    x = layers.BatchNormalization()(x)
    
    y = layers.Dense(2, activation="softmax")(x)

    model = Model(inputs=inputs, outputs=y)
    return model

# %%
train = pd.read_csv("./input/train.csv")
test = pd.read_csv("./input/test.csv")
sample = pd.read_csv("./input/sample_submission.csv")

test["target"] = -1
data = pd.concat([train, test]).reset_index(drop=True)

# %%
data['ord_5_1']=data['ord_5'].str[0].str.lower()

data['ord_5_2']=data['ord_5'].str[1].str.lower()

data=data.drop(['ord_5'],axis=1)

# %%
from sklearn.impute import SimpleImputer
col=set(data.columns)-set(["id", "target"])

imp = SimpleImputer(strategy="most_frequent",verbose=2)
target=data.target

data=imp.fit_transform(data.drop(["id", "target"],axis=1))

# %%
features = [x for x in data.columns if x not in ["id", "target"]]

for feat in features:
    lbl_enc = preprocessing.LabelEncoder()
    data[feat] = lbl_enc.fit_transform(data[feat].fillna("-1").astype(str).values)

# %%
train = data[data.target != -1].reset_index(drop=True)
test = data[data.target == -1].reset_index(drop=True)
test_data = [test.loc[:, features].values[:, k] for k in range(test.loc[:, features].values.shape[1])]

# %%
oof_preds = np.zeros((len(train)))
test_preds = np.zeros((len(test)))
from keras.callbacks import ModelCheckpoint
NSPLIT=100
skf = StratifiedKFold(n_splits=NSPLIT)
for train_index, test_index in skf.split(train, train.target.values):
    X_train, X_test = train.iloc[train_index, :], train.iloc[test_index, :]
    X_train = X_train.reset_index(drop=True)
    X_test = X_test.reset_index(drop=True)
    y_train, y_test = X_train.target.values, X_test.target.values
    model = create_model(data, features)
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=[auc])
    X_train = [X_train.loc[:, features].values[:, k] for k in range(X_train.loc[:, features].values.shape[1])]
    X_test = [X_test.loc[:, features].values[:, k] for k in range(X_test.loc[:, features].values.shape[1])]
    
    es = callbacks.EarlyStopping(monitor='val_auc', min_delta=0.001, patience=5,
                                 verbose=1, mode='max', baseline=None, restore_best_weights=True)

    rlr = callbacks.ReduceLROnPlateau(monitor='val_auc', factor=0.5,
                                      patience=3, min_lr=1e-6, mode='max', verbose=1)
    
    checkpoint_name = 'Weights-{epoch:03d}--{val_loss:.5f}.hdf5'
    checkpoint = ModelCheckpoint(checkpoint_name,monitor='val_loss',verbose = 1, save_best_only = True, mode ='auto')
    
    model.fit(X_train,
              utils.to_categorical(y_train),
              validation_data=(X_test, utils.to_categorical(y_test)),
              verbose=1,
              batch_size=1024,
              callbacks=[es, rlr, checkpoint],
              epochs=100
             )
    valid_fold_preds = model.predict(X_test)[:, 1]
    test_fold_preds = model.predict(test_data)[:, 1]
    oof_preds[test_index] = valid_fold_preds.ravel()
    test_preds += test_fold_preds.ravel()
    print(metrics.roc_auc_score(y_test, valid_fold_preds))
    K.clear_session()
# Out:
# WARNING:tensorflow:From /home/aniss/.local/lib/python3.7/site-packages/tensorflow/python/keras/initializers.py:119: calling RandomUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Using TensorFlow backend.
# WARNING:tensorflow:From /home/aniss/.local/lib/python3.7/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Train on 594000 samples, validate on 6000 samples
# WARNING:tensorflow:From /home/aniss/.local/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4642 - auc: 0.7054
# Epoch 00001: val_loss improved from inf to 0.41251, saving model to Weights-001--0.41251.hdf5
# 594000/594000 [==============================] - 14s 24us/sample - loss: 0.4642 - auc: 0.7055 - val_loss: 0.4125 - val_auc: 0.7690
# Epoch 2/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4084 - auc: 0.7699
# Epoch 00002: val_loss improved from 0.41251 to 0.40597, saving model to Weights-002--0.40597.hdf5
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.4084 - auc: 0.7699 - val_loss: 0.4060 - val_auc: 0.7709
# Epoch 3/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4038 - auc: 0.7775
# Epoch 00003: val_loss improved from 0.40597 to 0.40474, saving model to Weights-003--0.40474.hdf5
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.4039 - auc: 0.7774 - val_loss: 0.4047 - val_auc: 0.7732
# Epoch 4/100
# 592896/594000 [============================>.] - ETA: 0s - loss: 0.3999 - auc: 0.7836
# Epoch 00004: val_loss did not improve from 0.40474
# 594000/594000 [==============================] - 12s 21us/sample - loss: 0.3999 - auc: 0.7836 - val_loss: 0.4059 - val_auc: 0.7694
# Epoch 5/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3957 - auc: 0.7899
# Epoch 00005: val_loss did not improve from 0.40474
# 594000/594000 [==============================] - 12s 21us/sample - loss: 0.3956 - auc: 0.7899 - val_loss: 0.4083 - val_auc: 0.7673
# Epoch 6/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3893 - auc: 0.7995
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00006: val_loss did not improve from 0.40474
# 594000/594000 [==============================] - 13s 22us/sample - loss: 0.3893 - auc: 0.7995 - val_loss: 0.4094 - val_auc: 0.7687
# Epoch 7/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3709 - auc: 0.8238
# Epoch 00007: val_loss did not improve from 0.40474
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.3709 - auc: 0.8239 - val_loss: 0.4271 - val_auc: 0.7568
# Epoch 8/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3581 - auc: 0.8393Restoring model weights from the end of the best epoch.
#
# Epoch 00008: val_loss did not improve from 0.40474
# 594000/594000 [==============================] - 12s 21us/sample - loss: 0.3581 - auc: 0.8394 - val_loss: 0.4372 - val_auc: 0.7505
# Epoch 00008: early stopping
# 0.773185638296027
# Train on 594000 samples, validate on 6000 samples
# Epoch 1/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4633 - auc: 0.7070
# Epoch 00001: val_loss improved from inf to 0.41655, saving model to Weights-001--0.41655.hdf5
# 594000/594000 [==============================] - 14s 24us/sample - loss: 0.4633 - auc: 0.7070 - val_loss: 0.4166 - val_auc: 0.7679
# Epoch 2/100
# 592896/594000 [============================>.] - ETA: 0s - loss: 0.4081 - auc: 0.7705
# Epoch 00002: val_loss improved from 0.41655 to 0.40865, saving model to Weights-002--0.40865.hdf5
# 594000/594000 [==============================] - 12s 21us/sample - loss: 0.4080 - auc: 0.7707 - val_loss: 0.4086 - val_auc: 0.7694
# Epoch 3/100
# 592896/594000 [============================>.] - ETA: 0s - loss: 0.4036 - auc: 0.7780
# Epoch 00003: val_loss improved from 0.40865 to 0.40556, saving model to Weights-003--0.40556.hdf5
# 594000/594000 [==============================] - 12s 21us/sample - loss: 0.4036 - auc: 0.7780 - val_loss: 0.4056 - val_auc: 0.7732
# Epoch 4/100
# 592896/594000 [============================>.] - ETA: 0s - loss: 0.3999 - auc: 0.7836
# Epoch 00004: val_loss did not improve from 0.40556
# 594000/594000 [==============================] - 12s 21us/sample - loss: 0.3999 - auc: 0.7835 - val_loss: 0.4103 - val_auc: 0.7706
# Epoch 5/100
# 592896/594000 [============================>.] - ETA: 0s - loss: 0.3950 - auc: 0.7909
# Epoch 00005: val_loss did not improve from 0.40556
# 594000/594000 [==============================] - 12s 21us/sample - loss: 0.3950 - auc: 0.7909 - val_loss: 0.4086 - val_auc: 0.7680
# Epoch 6/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3885 - auc: 0.8005
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00006: val_loss did not improve from 0.40556
# 594000/594000 [==============================] - 12s 21us/sample - loss: 0.3885 - auc: 0.8005 - val_loss: 0.4166 - val_auc: 0.7646
# Epoch 7/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3691 - auc: 0.8261
# Epoch 00007: val_loss did not improve from 0.40556
# 594000/594000 [==============================] - 12s 21us/sample - loss: 0.3691 - auc: 0.8260 - val_loss: 0.4257 - val_auc: 0.7536
# Epoch 8/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3567 - auc: 0.8412Restoring model weights from the end of the best epoch.
#
# Epoch 00008: val_loss did not improve from 0.40556
# 594000/594000 [==============================] - 13s 21us/sample - loss: 0.3567 - auc: 0.8413 - val_loss: 0.4375 - val_auc: 0.7452
# Epoch 00008: early stopping
# 0.7727607606606035
# Train on 594000 samples, validate on 6000 samples
# Epoch 1/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4639 - auc: 0.7061
# Epoch 00001: val_loss improved from inf to 0.40387, saving model to Weights-001--0.40387.hdf5
# 594000/594000 [==============================] - 14s 24us/sample - loss: 0.4639 - auc: 0.7062 - val_loss: 0.4039 - val_auc: 0.7852
# Epoch 2/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4085 - auc: 0.7698
# Epoch 00002: val_loss improved from 0.40387 to 0.39859, saving model to Weights-002--0.39859.hdf5
# 594000/594000 [==============================] - 12s 21us/sample - loss: 0.4085 - auc: 0.7697 - val_loss: 0.3986 - val_auc: 0.7858
# Epoch 3/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4038 - auc: 0.7776
# Epoch 00003: val_loss improved from 0.39859 to 0.39440, saving model to Weights-003--0.39440.hdf5
# 594000/594000 [==============================] - 12s 21us/sample - loss: 0.4038 - auc: 0.7777 - val_loss: 0.3944 - val_auc: 0.7931
# Epoch 4/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4003 - auc: 0.7828
# Epoch 00004: val_loss did not improve from 0.39440
# 594000/594000 [==============================] - 12s 21us/sample - loss: 0.4003 - auc: 0.7829 - val_loss: 0.3994 - val_auc: 0.7877
# Epoch 5/100
# 592896/594000 [============================>.] - ETA: 0s - loss: 0.3962 - auc: 0.7891
# Epoch 00005: val_loss did not improve from 0.39440
# 594000/594000 [==============================] - 12s 21us/sample - loss: 0.3962 - auc: 0.7890 - val_loss: 0.4015 - val_auc: 0.7828
# Epoch 6/100
# 592896/594000 [============================>.] - ETA: 0s - loss: 0.3897 - auc: 0.7987
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00006: val_loss did not improve from 0.39440
# 594000/594000 [==============================] - 12s 21us/sample - loss: 0.3897 - auc: 0.7988 - val_loss: 0.4054 - val_auc: 0.7818
# Epoch 7/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3708 - auc: 0.8237
# Epoch 00007: val_loss did not improve from 0.39440
# 594000/594000 [==============================] - 12s 21us/sample - loss: 0.3708 - auc: 0.8237 - val_loss: 0.4167 - val_auc: 0.7655
# Epoch 8/100
# 592896/594000 [============================>.] - ETA: 0s - loss: 0.3576 - auc: 0.8397Restoring model weights from the end of the best epoch.
#
# Epoch 00008: val_loss did not improve from 0.39440
# 594000/594000 [==============================] - 13s 21us/sample - loss: 0.3576 - auc: 0.8397 - val_loss: 0.4225 - val_auc: 0.7600
# Epoch 00008: early stopping
# 0.7928390133709557
# Train on 594000 samples, validate on 6000 samples
# Epoch 1/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4611 - auc: 0.7079
# Epoch 00001: val_loss improved from inf to 0.40457, saving model to Weights-001--0.40457.hdf5
# 594000/594000 [==============================] - 14s 24us/sample - loss: 0.4611 - auc: 0.7080 - val_loss: 0.4046 - val_auc: 0.7815
# Epoch 2/100
# 591872/594000 [============================>.] - ETA: 0s - loss: 0.4087 - auc: 0.7696
# Epoch 00002: val_loss improved from 0.40457 to 0.39902, saving model to Weights-002--0.39902.hdf5
# 594000/594000 [==============================] - 12s 21us/sample - loss: 0.4087 - auc: 0.7696 - val_loss: 0.3990 - val_auc: 0.7834
# Epoch 3/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4038 - auc: 0.7775
# Epoch 00003: val_loss did not improve from 0.39902
# 594000/594000 [==============================] - 12s 21us/sample - loss: 0.4037 - auc: 0.7777 - val_loss: 0.3994 - val_auc: 0.7844
# Epoch 4/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4003 - auc: 0.7828
# Epoch 00004: val_loss did not improve from 0.39902
# 594000/594000 [==============================] - 12s 21us/sample - loss: 0.4003 - auc: 0.7826 - val_loss: 0.4031 - val_auc: 0.7810
# Epoch 5/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3956 - auc: 0.7899
# Epoch 00005: val_loss did not improve from 0.39902
# 594000/594000 [==============================] - 12s 21us/sample - loss: 0.3956 - auc: 0.7901 - val_loss: 0.4040 - val_auc: 0.7808
# Epoch 6/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3884 - auc: 0.8005
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00006: val_loss did not improve from 0.39902
# 594000/594000 [==============================] - 12s 21us/sample - loss: 0.3884 - auc: 0.8004 - val_loss: 0.4044 - val_auc: 0.7767
# Epoch 7/100
# 592896/594000 [============================>.] - ETA: 0s - loss: 0.3695 - auc: 0.8260
# Epoch 00007: val_loss did not improve from 0.39902
# 594000/594000 [==============================] - 12s 21us/sample - loss: 0.3695 - auc: 0.8260 - val_loss: 0.4193 - val_auc: 0.7644
# Epoch 8/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3563 - auc: 0.8417Restoring model weights from the end of the best epoch.
#
# Epoch 00008: val_loss did not improve from 0.39902
# 594000/594000 [==============================] - 13s 21us/sample - loss: 0.3563 - auc: 0.8417 - val_loss: 0.4250 - val_auc: 0.7590
# Epoch 00008: early stopping
# 0.7849945708051185
# Train on 594000 samples, validate on 6000 samples
# Epoch 1/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4624 - auc: 0.7075
# Epoch 00001: val_loss improved from inf to 0.41189, saving model to Weights-001--0.41189.hdf5
# 594000/594000 [==============================] - 14s 24us/sample - loss: 0.4624 - auc: 0.7076 - val_loss: 0.4119 - val_auc: 0.7834
# Epoch 2/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4084 - auc: 0.7700
# Epoch 00002: val_loss improved from 0.41189 to 0.40097, saving model to Weights-002--0.40097.hdf5
# 594000/594000 [==============================] - 12s 21us/sample - loss: 0.4084 - auc: 0.7699 - val_loss: 0.4010 - val_auc: 0.7866
# Epoch 3/100
# 592896/594000 [============================>.] - ETA: 0s - loss: 0.4038 - auc: 0.7776
# Epoch 00003: val_loss improved from 0.40097 to 0.40085, saving model to Weights-003--0.40085.hdf5
# 594000/594000 [==============================] - 12s 21us/sample - loss: 0.4038 - auc: 0.7776 - val_loss: 0.4009 - val_auc: 0.7810
# Epoch 4/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4000 - auc: 0.7834
# Epoch 00004: val_loss improved from 0.40085 to 0.39727, saving model to Weights-004--0.39727.hdf5
# 594000/594000 [==============================] - 12s 21us/sample - loss: 0.4000 - auc: 0.7833 - val_loss: 0.3973 - val_auc: 0.7886
# Epoch 5/100
# 592896/594000 [============================>.] - ETA: 0s - loss: 0.3956 - auc: 0.7900
# Epoch 00005: val_loss did not improve from 0.39727
# 594000/594000 [==============================] - 12s 21us/sample - loss: 0.3956 - auc: 0.7899 - val_loss: 0.4005 - val_auc: 0.7806
# Epoch 6/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3885 - auc: 0.8004
# Epoch 00006: val_loss did not improve from 0.39727
# 594000/594000 [==============================] - 12s 21us/sample - loss: 0.3885 - auc: 0.8004 - val_loss: 0.4060 - val_auc: 0.7762
# Epoch 7/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3795 - auc: 0.8129
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00007: val_loss did not improve from 0.39727
# 594000/594000 [==============================] - 12s 21us/sample - loss: 0.3795 - auc: 0.8129 - val_loss: 0.4085 - val_auc: 0.7702
# Epoch 8/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3552 - auc: 0.8428
# Epoch 00008: val_loss did not improve from 0.39727
# 594000/594000 [==============================] - 12s 21us/sample - loss: 0.3552 - auc: 0.8429 - val_loss: 0.4247 - val_auc: 0.7609
# Epoch 9/100
# 592896/594000 [============================>.] - ETA: 0s - loss: 0.3421 - auc: 0.8569Restoring model weights from the end of the best epoch.
#
# Epoch 00009: val_loss did not improve from 0.39727
# 594000/594000 [==============================] - 13s 21us/sample - loss: 0.3422 - auc: 0.8568 - val_loss: 0.4358 - val_auc: 0.7544
# Epoch 00009: early stopping
# 0.7887193253227983
# Train on 594000 samples, validate on 6000 samples
# Epoch 1/100
# 591872/594000 [============================>.] - ETA: 0s - loss: 0.4631 - auc: 0.7074
# Epoch 00001: val_loss improved from inf to 0.41355, saving model to Weights-001--0.41355.hdf5
# 594000/594000 [==============================] - 15s 25us/sample - loss: 0.4629 - auc: 0.7076 - val_loss: 0.4135 - val_auc: 0.7759
# Epoch 2/100
# 591872/594000 [============================>.] - ETA: 0s - loss: 0.4088 - auc: 0.7694
# Epoch 00002: val_loss improved from 0.41355 to 0.40282, saving model to Weights-002--0.40282.hdf5
# 594000/594000 [==============================] - 12s 21us/sample - loss: 0.4088 - auc: 0.7693 - val_loss: 0.4028 - val_auc: 0.7789
# Epoch 3/100
# 591872/594000 [============================>.] - ETA: 0s - loss: 0.4035 - auc: 0.7779
# Epoch 00003: val_loss did not improve from 0.40282
# 594000/594000 [==============================] - 13s 21us/sample - loss: 0.4035 - auc: 0.7778 - val_loss: 0.4030 - val_auc: 0.7795
# Epoch 4/100
# 592896/594000 [============================>.] - ETA: 0s - loss: 0.4001 - auc: 0.7829
# Epoch 00004: val_loss did not improve from 0.40282
# 594000/594000 [==============================] - 12s 21us/sample - loss: 0.4001 - auc: 0.7829 - val_loss: 0.4052 - val_auc: 0.7770
# Epoch 5/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3951 - auc: 0.7904
# Epoch 00005: val_loss did not improve from 0.40282
# 594000/594000 [==============================] - 12s 21us/sample - loss: 0.3951 - auc: 0.7903 - val_loss: 0.4059 - val_auc: 0.7760
# Epoch 6/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3885 - auc: 0.8005
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00006: val_loss did not improve from 0.40282
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.3885 - auc: 0.8005 - val_loss: 0.4112 - val_auc: 0.7724
# Epoch 7/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3694 - auc: 0.8258Restoring model weights from the end of the best epoch.
#
# Epoch 00007: val_loss did not improve from 0.40282
# 594000/594000 [==============================] - 12s 21us/sample - loss: 0.3694 - auc: 0.8258 - val_loss: 0.4195 - val_auc: 0.7671
# Epoch 00007: early stopping
# 0.7786692438072761
# Train on 594000 samples, validate on 6000 samples
# Epoch 1/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4614 - auc: 0.7095
# Epoch 00001: val_loss improved from inf to 0.41899, saving model to Weights-001--0.41899.hdf5
# 594000/594000 [==============================] - 14s 23us/sample - loss: 0.4614 - auc: 0.7097 - val_loss: 0.4190 - val_auc: 0.7647
# Epoch 2/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4080 - auc: 0.7706
# Epoch 00002: val_loss improved from 0.41899 to 0.41428, saving model to Weights-002--0.41428.hdf5
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.4080 - auc: 0.7706 - val_loss: 0.4143 - val_auc: 0.7611
# Epoch 3/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4037 - auc: 0.7776
# Epoch 00003: val_loss improved from 0.41428 to 0.41148, saving model to Weights-003--0.41148.hdf5
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.4037 - auc: 0.7777 - val_loss: 0.4115 - val_auc: 0.7623
# Epoch 4/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4002 - auc: 0.7828
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00004: val_loss did not improve from 0.41148
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.4002 - auc: 0.7828 - val_loss: 0.4192 - val_auc: 0.7624
# Epoch 5/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3896 - auc: 0.7983
# Epoch 00005: val_loss did not improve from 0.41148
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.3896 - auc: 0.7983 - val_loss: 0.4191 - val_auc: 0.7544
# Epoch 6/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3831 - auc: 0.8075Restoring model weights from the end of the best epoch.
#
# Epoch 00006: val_loss did not improve from 0.41148
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.3831 - auc: 0.8076 - val_loss: 0.4265 - val_auc: 0.7515
# Epoch 00006: early stopping
# 0.7656192742169753
# Train on 594000 samples, validate on 6000 samples
# Epoch 1/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4625 - auc: 0.7075
# Epoch 00001: val_loss improved from inf to 0.40852, saving model to Weights-001--0.40852.hdf5
# 594000/594000 [==============================] - 14s 23us/sample - loss: 0.4624 - auc: 0.7077 - val_loss: 0.4085 - val_auc: 0.7746
# Epoch 2/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4089 - auc: 0.7693
# Epoch 00002: val_loss improved from 0.40852 to 0.40355, saving model to Weights-002--0.40355.hdf5
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.4089 - auc: 0.7692 - val_loss: 0.4036 - val_auc: 0.7789
# Epoch 3/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4040 - auc: 0.7773
# Epoch 00003: val_loss improved from 0.40355 to 0.40285, saving model to Weights-003--0.40285.hdf5
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.4040 - auc: 0.7772 - val_loss: 0.4029 - val_auc: 0.7788
# Epoch 4/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4003 - auc: 0.7830
# Epoch 00004: val_loss did not improve from 0.40285
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.4002 - auc: 0.7830 - val_loss: 0.4041 - val_auc: 0.7793
# Epoch 5/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3953 - auc: 0.7902
# Epoch 00005: val_loss did not improve from 0.40285
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.3953 - auc: 0.7902 - val_loss: 0.4048 - val_auc: 0.7765
# Epoch 6/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3891 - auc: 0.7997
# Epoch 00006: val_loss did not improve from 0.40285
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.3891 - auc: 0.7997 - val_loss: 0.4097 - val_auc: 0.7692
# Epoch 7/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3796 - auc: 0.8128Restoring model weights from the end of the best epoch.
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00007: val_loss did not improve from 0.40285
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.3796 - auc: 0.8128 - val_loss: 0.4144 - val_auc: 0.7639
# Epoch 00007: early stopping
# 0.7789685935637337
# Train on 594000 samples, validate on 6000 samples
# Epoch 1/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4624 - auc: 0.7077
# Epoch 00001: val_loss improved from inf to 0.41279, saving model to Weights-001--0.41279.hdf5
# 594000/594000 [==============================] - 14s 23us/sample - loss: 0.4623 - auc: 0.7079 - val_loss: 0.4128 - val_auc: 0.7662
# Epoch 2/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4086 - auc: 0.7699
# Epoch 00002: val_loss did not improve from 0.41279
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.4086 - auc: 0.7700 - val_loss: 0.4133 - val_auc: 0.7654
# Epoch 3/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4036 - auc: 0.7778
# Epoch 00003: val_loss did not improve from 0.41279
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.4036 - auc: 0.7778 - val_loss: 0.4131 - val_auc: 0.7620
# Epoch 4/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4003 - auc: 0.7829
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00004: val_loss improved from 0.41279 to 0.41126, saving model to Weights-004--0.41126.hdf5
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.4003 - auc: 0.7826 - val_loss: 0.4113 - val_auc: 0.7627
# Epoch 5/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3902 - auc: 0.7976
# Epoch 00005: val_loss did not improve from 0.41126
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.3902 - auc: 0.7976 - val_loss: 0.4178 - val_auc: 0.7599
# Epoch 6/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3832 - auc: 0.8076Restoring model weights from the end of the best epoch.
#
# Epoch 00006: val_loss did not improve from 0.41126
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.3831 - auc: 0.8076 - val_loss: 0.4253 - val_auc: 0.7558
# Epoch 00006: early stopping
# 0.7664609957035686
# Train on 594000 samples, validate on 6000 samples
# Epoch 1/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4617 - auc: 0.7080
# Epoch 00001: val_loss improved from inf to 0.41512, saving model to Weights-001--0.41512.hdf5
# 594000/594000 [==============================] - 14s 23us/sample - loss: 0.4617 - auc: 0.7080 - val_loss: 0.4151 - val_auc: 0.7777
# Epoch 2/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4084 - auc: 0.7699
# Epoch 00002: val_loss improved from 0.41512 to 0.40278, saving model to Weights-002--0.40278.hdf5
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.4084 - auc: 0.7700 - val_loss: 0.4028 - val_auc: 0.7797
# Epoch 3/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4034 - auc: 0.7785
# Epoch 00003: val_loss improved from 0.40278 to 0.40213, saving model to Weights-003--0.40213.hdf5
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.4034 - auc: 0.7784 - val_loss: 0.4021 - val_auc: 0.7812
# Epoch 4/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3997 - auc: 0.7838
# Epoch 00004: val_loss did not improve from 0.40213
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.3997 - auc: 0.7839 - val_loss: 0.4064 - val_auc: 0.7813
# Epoch 5/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3948 - auc: 0.7912
# Epoch 00005: val_loss did not improve from 0.40213
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.3948 - auc: 0.7911 - val_loss: 0.4052 - val_auc: 0.7798
# Epoch 6/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3882 - auc: 0.8006
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00006: val_loss did not improve from 0.40213
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.3882 - auc: 0.8008 - val_loss: 0.4100 - val_auc: 0.7751
# Epoch 7/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3683 - auc: 0.8269
# Epoch 00007: val_loss did not improve from 0.40213
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.3683 - auc: 0.8270 - val_loss: 0.4222 - val_auc: 0.7546
# Epoch 8/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3557 - auc: 0.8420Restoring model weights from the end of the best epoch.
#
# Epoch 00008: val_loss did not improve from 0.40213
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.3557 - auc: 0.8421 - val_loss: 0.4358 - val_auc: 0.7482
# Epoch 00008: early stopping
# 0.7814912931124358
# Train on 594000 samples, validate on 6000 samples
# Epoch 1/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4644 - auc: 0.7047
# Epoch 00001: val_loss improved from inf to 0.41204, saving model to Weights-001--0.41204.hdf5
# 594000/594000 [==============================] - 14s 23us/sample - loss: 0.4644 - auc: 0.7047 - val_loss: 0.4120 - val_auc: 0.7754
# Epoch 2/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4086 - auc: 0.7693
# Epoch 00002: val_loss improved from 0.41204 to 0.40371, saving model to Weights-002--0.40371.hdf5
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.4086 - auc: 0.7694 - val_loss: 0.4037 - val_auc: 0.7781
# Epoch 3/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4039 - auc: 0.7775
# Epoch 00003: val_loss did not improve from 0.40371
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.4039 - auc: 0.7775 - val_loss: 0.4064 - val_auc: 0.7744
# Epoch 4/100
# 591872/594000 [============================>.] - ETA: 0s - loss: 0.4005 - auc: 0.7831
# Epoch 00004: val_loss did not improve from 0.40371
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.4004 - auc: 0.7831 - val_loss: 0.4056 - val_auc: 0.7747
# Epoch 5/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3957 - auc: 0.7898
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00005: val_loss did not improve from 0.40371
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.3957 - auc: 0.7898 - val_loss: 0.4075 - val_auc: 0.7751
# Epoch 6/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3821 - auc: 0.8088
# Epoch 00006: val_loss did not improve from 0.40371
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.3821 - auc: 0.8088 - val_loss: 0.4185 - val_auc: 0.7652
# Epoch 7/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3720 - auc: 0.8223Restoring model weights from the end of the best epoch.
#
# Epoch 00007: val_loss did not improve from 0.40371
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.3720 - auc: 0.8224 - val_loss: 0.4290 - val_auc: 0.7606
# Epoch 00007: early stopping
# 0.7778790115743095
# Train on 594000 samples, validate on 6000 samples
# Epoch 1/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4608 - auc: 0.7095
# Epoch 00001: val_loss improved from inf to 0.40532, saving model to Weights-001--0.40532.hdf5
# 594000/594000 [==============================] - 14s 23us/sample - loss: 0.4608 - auc: 0.7096 - val_loss: 0.4053 - val_auc: 0.7833
# Epoch 2/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4082 - auc: 0.7702
# Epoch 00002: val_loss improved from 0.40532 to 0.40122, saving model to Weights-002--0.40122.hdf5
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.4082 - auc: 0.7702 - val_loss: 0.4012 - val_auc: 0.7802
# Epoch 3/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4040 - auc: 0.7774
# Epoch 00003: val_loss improved from 0.40122 to 0.40031, saving model to Weights-003--0.40031.hdf5
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.4040 - auc: 0.7775 - val_loss: 0.4003 - val_auc: 0.7819
# Epoch 4/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3998 - auc: 0.7837
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00004: val_loss did not improve from 0.40031
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.3998 - auc: 0.7835 - val_loss: 0.4013 - val_auc: 0.7792
# Epoch 5/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3900 - auc: 0.7980
# Epoch 00005: val_loss did not improve from 0.40031
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.3900 - auc: 0.7980 - val_loss: 0.4058 - val_auc: 0.7782
# Epoch 6/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3821 - auc: 0.8089Restoring model weights from the end of the best epoch.
#
# Epoch 00006: val_loss did not improve from 0.40031
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.3821 - auc: 0.8089 - val_loss: 0.4081 - val_auc: 0.7741
# Epoch 00006: early stopping
# 0.7827906664224884
# Train on 594000 samples, validate on 6000 samples
# Epoch 1/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4611 - auc: 0.7098
# Epoch 00001: val_loss improved from inf to 0.42360, saving model to Weights-001--0.42360.hdf5
# 594000/594000 [==============================] - 14s 23us/sample - loss: 0.4612 - auc: 0.7099 - val_loss: 0.4236 - val_auc: 0.7660
# Epoch 2/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4084 - auc: 0.7703
# Epoch 00002: val_loss improved from 0.42360 to 0.41074, saving model to Weights-002--0.41074.hdf5
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.4084 - auc: 0.7701 - val_loss: 0.4107 - val_auc: 0.7667
# Epoch 3/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4039 - auc: 0.7776
# Epoch 00003: val_loss improved from 0.41074 to 0.40921, saving model to Weights-003--0.40921.hdf5
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.4039 - auc: 0.7776 - val_loss: 0.4092 - val_auc: 0.7689
# Epoch 4/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3998 - auc: 0.7836
# Epoch 00004: val_loss did not improve from 0.40921
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.3998 - auc: 0.7835 - val_loss: 0.4094 - val_auc: 0.7681
# Epoch 5/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3955 - auc: 0.7902
# Epoch 00005: val_loss did not improve from 0.40921
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.3955 - auc: 0.7901 - val_loss: 0.4123 - val_auc: 0.7648
# Epoch 6/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3886 - auc: 0.8005
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00006: val_loss did not improve from 0.40921
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.3886 - auc: 0.8005 - val_loss: 0.4188 - val_auc: 0.7570
# Epoch 7/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3690 - auc: 0.8261
# Epoch 00007: val_loss did not improve from 0.40921
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.3691 - auc: 0.8261 - val_loss: 0.4337 - val_auc: 0.7475
# Epoch 8/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3567 - auc: 0.8410Restoring model weights from the end of the best epoch.
#
# Epoch 00008: val_loss did not improve from 0.40921
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.3567 - auc: 0.8410 - val_loss: 0.4407 - val_auc: 0.7428
# Epoch 00008: early stopping
# 0.7687983704564157
# Train on 594000 samples, validate on 6000 samples
# Epoch 1/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4625 - auc: 0.7068
# Epoch 00001: val_loss improved from inf to 0.40799, saving model to Weights-001--0.40799.hdf5
# 594000/594000 [==============================] - 14s 23us/sample - loss: 0.4625 - auc: 0.7070 - val_loss: 0.4080 - val_auc: 0.7730
# Epoch 2/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4085 - auc: 0.7698
# Epoch 00002: val_loss improved from 0.40799 to 0.40383, saving model to Weights-002--0.40383.hdf5
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.4085 - auc: 0.7697 - val_loss: 0.4038 - val_auc: 0.7760
# Epoch 3/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4034 - auc: 0.7782
# Epoch 00003: val_loss did not improve from 0.40383
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.4034 - auc: 0.7781 - val_loss: 0.4043 - val_auc: 0.7728
# Epoch 4/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3999 - auc: 0.7835
# Epoch 00004: val_loss did not improve from 0.40383
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.3999 - auc: 0.7835 - val_loss: 0.4070 - val_auc: 0.7727
# Epoch 5/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3955 - auc: 0.7901
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00005: val_loss did not improve from 0.40383
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.3955 - auc: 0.7901 - val_loss: 0.4081 - val_auc: 0.7696
# Epoch 6/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3816 - auc: 0.8099
# Epoch 00006: val_loss did not improve from 0.40383
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.3816 - auc: 0.8099 - val_loss: 0.4157 - val_auc: 0.7602
# Epoch 7/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3717 - auc: 0.8229Restoring model weights from the end of the best epoch.
#
# Epoch 00007: val_loss did not improve from 0.40383
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.3717 - auc: 0.8231 - val_loss: 0.4211 - val_auc: 0.7558
# Epoch 00007: early stopping
# 0.7753220771495257
# Train on 594000 samples, validate on 6000 samples
# Epoch 1/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4637 - auc: 0.7064
# Epoch 00001: val_loss improved from inf to 0.41257, saving model to Weights-001--0.41257.hdf5
# 594000/594000 [==============================] - 14s 23us/sample - loss: 0.4637 - auc: 0.7064 - val_loss: 0.4126 - val_auc: 0.7711
# Epoch 2/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4087 - auc: 0.7695
# Epoch 00002: val_loss improved from 0.41257 to 0.40415, saving model to Weights-002--0.40415.hdf5
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.4087 - auc: 0.7697 - val_loss: 0.4041 - val_auc: 0.7764
# Epoch 3/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4039 - auc: 0.7774
# Epoch 00003: val_loss did not improve from 0.40415
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.4039 - auc: 0.7775 - val_loss: 0.4065 - val_auc: 0.7749
# Epoch 4/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4001 - auc: 0.7835
# Epoch 00004: val_loss did not improve from 0.40415
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.4001 - auc: 0.7836 - val_loss: 0.4070 - val_auc: 0.7750
# Epoch 5/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3957 - auc: 0.7899
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00005: val_loss did not improve from 0.40415
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.3957 - auc: 0.7896 - val_loss: 0.4078 - val_auc: 0.7728
# Epoch 6/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3821 - auc: 0.8090
# Epoch 00006: val_loss did not improve from 0.40415
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.3821 - auc: 0.8090 - val_loss: 0.4170 - val_auc: 0.7608
# Epoch 7/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3716 - auc: 0.8227Restoring model weights from the end of the best epoch.
#
# Epoch 00007: val_loss did not improve from 0.40415
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.3716 - auc: 0.8225 - val_loss: 0.4251 - val_auc: 0.7537
# Epoch 00007: early stopping
# 0.7761800487906325
# Train on 594000 samples, validate on 6000 samples
# Epoch 1/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4632 - auc: 0.7069
# Epoch 00001: val_loss improved from inf to 0.40812, saving model to Weights-001--0.40812.hdf5
# 594000/594000 [==============================] - 14s 23us/sample - loss: 0.4632 - auc: 0.7071 - val_loss: 0.4081 - val_auc: 0.7771
# Epoch 2/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4087 - auc: 0.7695
# Epoch 00002: val_loss improved from 0.40812 to 0.40085, saving model to Weights-002--0.40085.hdf5
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.4087 - auc: 0.7693 - val_loss: 0.4008 - val_auc: 0.7802
# Epoch 3/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4038 - auc: 0.7777
# Epoch 00003: val_loss did not improve from 0.40085
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.4038 - auc: 0.7777 - val_loss: 0.4029 - val_auc: 0.7780
# Epoch 4/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4005 - auc: 0.7826
# Epoch 00004: val_loss did not improve from 0.40085
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.4004 - auc: 0.7827 - val_loss: 0.4023 - val_auc: 0.7792
# Epoch 5/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3957 - auc: 0.7897
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00005: val_loss did not improve from 0.40085
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.3958 - auc: 0.7897 - val_loss: 0.4104 - val_auc: 0.7755
# Epoch 6/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3820 - auc: 0.8090
# Epoch 00006: val_loss did not improve from 0.40085
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.3820 - auc: 0.8089 - val_loss: 0.4119 - val_auc: 0.7655
# Epoch 7/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3717 - auc: 0.8228Restoring model weights from the end of the best epoch.
#
# Epoch 00007: val_loss did not improve from 0.40085
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.3717 - auc: 0.8229 - val_loss: 0.4207 - val_auc: 0.7602
# Epoch 00007: early stopping
# 0.7807153025879192
# Train on 594000 samples, validate on 6000 samples
# Epoch 1/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4613 - auc: 0.7090
# Epoch 00001: val_loss improved from inf to 0.40975, saving model to Weights-001--0.40975.hdf5
# 594000/594000 [==============================] - 14s 23us/sample - loss: 0.4613 - auc: 0.7092 - val_loss: 0.4098 - val_auc: 0.7850
# Epoch 2/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4086 - auc: 0.7697
# Epoch 00002: val_loss improved from 0.40975 to 0.39870, saving model to Weights-002--0.39870.hdf5
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.4086 - auc: 0.7696 - val_loss: 0.3987 - val_auc: 0.7856
# Epoch 3/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4035 - auc: 0.7781
# Epoch 00003: val_loss improved from 0.39870 to 0.39717, saving model to Weights-003--0.39717.hdf5
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.4035 - auc: 0.7781 - val_loss: 0.3972 - val_auc: 0.7836
# Epoch 4/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3999 - auc: 0.7837
# Epoch 00004: val_loss did not improve from 0.39717
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.3999 - auc: 0.7838 - val_loss: 0.3989 - val_auc: 0.7839
# Epoch 5/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3952 - auc: 0.7904
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00005: val_loss did not improve from 0.39717
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.3952 - auc: 0.7902 - val_loss: 0.3989 - val_auc: 0.7817
# Epoch 6/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3806 - auc: 0.8111Restoring model weights from the end of the best epoch.
#
# Epoch 00006: val_loss did not improve from 0.39717
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.3806 - auc: 0.8110 - val_loss: 0.4064 - val_auc: 0.7772
# Epoch 00006: early stopping
# 0.7851052179246143
# Train on 594000 samples, validate on 6000 samples
# Epoch 1/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4640 - auc: 0.7051
# Epoch 00001: val_loss improved from inf to 0.41153, saving model to Weights-001--0.41153.hdf5
# 594000/594000 [==============================] - 14s 23us/sample - loss: 0.4640 - auc: 0.7052 - val_loss: 0.4115 - val_auc: 0.7737
# Epoch 2/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4083 - auc: 0.7697
# Epoch 00002: val_loss improved from 0.41153 to 0.40517, saving model to Weights-002--0.40517.hdf5
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.4083 - auc: 0.7695 - val_loss: 0.4052 - val_auc: 0.7788
# Epoch 3/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4033 - auc: 0.7783
# Epoch 00003: val_loss did not improve from 0.40517
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.4033 - auc: 0.7783 - val_loss: 0.4069 - val_auc: 0.7761
# Epoch 4/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3997 - auc: 0.7836
# Epoch 00004: val_loss did not improve from 0.40517
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.3997 - auc: 0.7835 - val_loss: 0.4057 - val_auc: 0.7756
# Epoch 5/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3958 - auc: 0.7898
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00005: val_loss did not improve from 0.40517
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.3958 - auc: 0.7896 - val_loss: 0.4081 - val_auc: 0.7711
# Epoch 6/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3809 - auc: 0.8106
# Epoch 00006: val_loss did not improve from 0.40517
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.3809 - auc: 0.8105 - val_loss: 0.4169 - val_auc: 0.7639
# Epoch 7/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3716 - auc: 0.8228Restoring model weights from the end of the best epoch.
#
# Epoch 00007: val_loss did not improve from 0.40517
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.3716 - auc: 0.8227 - val_loss: 0.4208 - val_auc: 0.7613
# Epoch 00007: early stopping
# 0.7783450623540339
# Train on 594000 samples, validate on 6000 samples
# Epoch 1/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4615 - auc: 0.7086
# Epoch 00001: val_loss improved from inf to 0.41271, saving model to Weights-001--0.41271.hdf5
# 594000/594000 [==============================] - 14s 23us/sample - loss: 0.4615 - auc: 0.7085 - val_loss: 0.4127 - val_auc: 0.7693
# Epoch 2/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4087 - auc: 0.7695
# Epoch 00002: val_loss improved from 0.41271 to 0.40328, saving model to Weights-002--0.40328.hdf5
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.4087 - auc: 0.7696 - val_loss: 0.4033 - val_auc: 0.7749
# Epoch 3/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4035 - auc: 0.7781
# Epoch 00003: val_loss did not improve from 0.40328
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.4035 - auc: 0.7781 - val_loss: 0.4061 - val_auc: 0.7727
# Epoch 4/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3996 - auc: 0.7840
# Epoch 00004: val_loss did not improve from 0.40328
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.3996 - auc: 0.7841 - val_loss: 0.4069 - val_auc: 0.7700
# Epoch 5/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3950 - auc: 0.7911
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00005: val_loss did not improve from 0.40328
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.3950 - auc: 0.7911 - val_loss: 0.4135 - val_auc: 0.7736
# Epoch 6/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3800 - auc: 0.8120
# Epoch 00006: val_loss did not improve from 0.40328
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.3800 - auc: 0.8121 - val_loss: 0.4208 - val_auc: 0.7617
# Epoch 7/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3691 - auc: 0.8260Restoring model weights from the end of the best epoch.
#
# Epoch 00007: val_loss did not improve from 0.40328
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.3691 - auc: 0.8259 - val_loss: 0.4239 - val_auc: 0.7569
# Epoch 00007: early stopping
# 0.7745477298990611
# Train on 594000 samples, validate on 6000 samples
# Epoch 1/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4646 - auc: 0.7053
# Epoch 00001: val_loss improved from inf to 0.40627, saving model to Weights-001--0.40627.hdf5
# 594000/594000 [==============================] - 14s 23us/sample - loss: 0.4646 - auc: 0.7055 - val_loss: 0.4063 - val_auc: 0.7762
# Epoch 2/100
# 592896/594000 [============================>.] - ETA: 0s - loss: 0.4085 - auc: 0.7695
# Epoch 00002: val_loss improved from 0.40627 to 0.40364, saving model to Weights-002--0.40364.hdf5
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.4085 - auc: 0.7695 - val_loss: 0.4036 - val_auc: 0.7817
# Epoch 3/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4039 - auc: 0.7774
# Epoch 00003: val_loss improved from 0.40364 to 0.40322, saving model to Weights-003--0.40322.hdf5
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.4039 - auc: 0.7774 - val_loss: 0.4032 - val_auc: 0.7785
# Epoch 4/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4004 - auc: 0.7828
# Epoch 00004: val_loss did not improve from 0.40322
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.4004 - auc: 0.7830 - val_loss: 0.4050 - val_auc: 0.7770
# Epoch 5/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3959 - auc: 0.7897
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00005: val_loss did not improve from 0.40322
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.3959 - auc: 0.7897 - val_loss: 0.4090 - val_auc: 0.7711
# Epoch 6/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3819 - auc: 0.8091
# Epoch 00006: val_loss did not improve from 0.40322
# ...
# Epoch 6/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3810 - auc: 0.8105
# Epoch 00006: val_loss did not improve from 0.40349
# 594000/594000 [==============================] - 12s 21us/sample - loss: 0.3810 - auc: 0.8105 - val_loss: 0.4169 - val_auc: 0.7675
# Epoch 7/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3708 - auc: 0.8239Restoring model weights from the end of the best epoch.
#
# Epoch 00007: val_loss did not improve from 0.40349
# 594000/594000 [==============================] - 12s 21us/sample - loss: 0.3708 - auc: 0.8240 - val_loss: 0.4197 - val_auc: 0.7618
# Epoch 00007: early stopping
# 0.7805308300660655
# Train on 594000 samples, validate on 6000 samples
# Epoch 1/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4615 - auc: 0.7092
# Epoch 00001: val_loss improved from inf to 0.41172, saving model to Weights-001--0.41172.hdf5
# 594000/594000 [==============================] - 14s 24us/sample - loss: 0.4615 - auc: 0.7090 - val_loss: 0.4117 - val_auc: 0.7816
# Epoch 2/100
# 592896/594000 [============================>.] - ETA: 0s - loss: 0.4082 - auc: 0.7701
# Epoch 00002: val_loss improved from 0.41172 to 0.40012, saving model to Weights-002--0.40012.hdf5
# 594000/594000 [==============================] - 12s 21us/sample - loss: 0.4082 - auc: 0.7702 - val_loss: 0.4001 - val_auc: 0.7873
# Epoch 3/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4035 - auc: 0.7780
# Epoch 00003: val_loss did not improve from 0.40012
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.4035 - auc: 0.7781 - val_loss: 0.4019 - val_auc: 0.7864
# Epoch 4/100
# 592896/594000 [============================>.] - ETA: 0s - loss: 0.4001 - auc: 0.7834
# Epoch 00004: val_loss did not improve from 0.40012
# 594000/594000 [==============================] - 12s 21us/sample - loss: 0.4001 - auc: 0.7835 - val_loss: 0.4009 - val_auc: 0.7845
# Epoch 5/100
# 592896/594000 [============================>.] - ETA: 0s - loss: 0.3951 - auc: 0.7910
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00005: val_loss did not improve from 0.40012
# 594000/594000 [==============================] - 12s 21us/sample - loss: 0.3951 - auc: 0.7910 - val_loss: 0.4168 - val_auc: 0.7760
# Epoch 6/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3803 - auc: 0.8113
# Epoch 00006: val_loss did not improve from 0.40012
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.3803 - auc: 0.8114 - val_loss: 0.4129 - val_auc: 0.7661
# Epoch 7/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3704 - auc: 0.8243Restoring model weights from the end of the best epoch.
#
# Epoch 00007: val_loss did not improve from 0.40012
# 594000/594000 [==============================] - 12s 21us/sample - loss: 0.3704 - auc: 0.8243 - val_loss: 0.4234 - val_auc: 0.7592
# Epoch 00007: early stopping
# 0.7875404333521147
# Train on 594000 samples, validate on 6000 samples
# Epoch 1/100
# 591872/594000 [============================>.] - ETA: 0s - loss: 0.4629 - auc: 0.7090
# Epoch 00001: val_loss improved from inf to 0.41246, saving model to Weights-001--0.41246.hdf5
# 594000/594000 [==============================] - 15s 25us/sample - loss: 0.4628 - auc: 0.7092 - val_loss: 0.4125 - val_auc: 0.7755
# Epoch 2/100
# 592896/594000 [============================>.] - ETA: 0s - loss: 0.4082 - auc: 0.7700
# Epoch 00002: val_loss improved from 0.41246 to 0.40487, saving model to Weights-002--0.40487.hdf5
# 594000/594000 [==============================] - 12s 21us/sample - loss: 0.4082 - auc: 0.7702 - val_loss: 0.4049 - val_auc: 0.7794
# Epoch 3/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4039 - auc: 0.7775
# Epoch 00003: val_loss did not improve from 0.40487
# 594000/594000 [==============================] - 12s 21us/sample - loss: 0.4039 - auc: 0.7776 - val_loss: 0.4053 - val_auc: 0.7719
# Epoch 4/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3995 - auc: 0.7840
# Epoch 00004: val_loss did not improve from 0.40487
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.3995 - auc: 0.7840 - val_loss: 0.4056 - val_auc: 0.7724
# Epoch 5/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3952 - auc: 0.7907
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00005: val_loss did not improve from 0.40487
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.3952 - auc: 0.7907 - val_loss: 0.4052 - val_auc: 0.7745
# Epoch 6/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3806 - auc: 0.8112
# Epoch 00006: val_loss did not improve from 0.40487
# 594000/594000 [==============================] - 13s 21us/sample - loss: 0.3807 - auc: 0.8110 - val_loss: 0.4184 - val_auc: 0.7592
# Epoch 7/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3703 - auc: 0.8245Restoring model weights from the end of the best epoch.
#
# Epoch 00007: val_loss did not improve from 0.40487
# 594000/594000 [==============================] - 12s 21us/sample - loss: 0.3703 - auc: 0.8245 - val_loss: 0.4218 - val_auc: 0.7519
# Epoch 00007: early stopping
# 0.7797000852457676
# Train on 594000 samples, validate on 6000 samples
# Epoch 1/100
# 592896/594000 [============================>.] - ETA: 0s - loss: 0.4640 - auc: 0.7051
# Epoch 00001: val_loss improved from inf to 0.41242, saving model to Weights-001--0.41242.hdf5
# 594000/594000 [==============================] - 14s 24us/sample - loss: 0.4639 - auc: 0.7054 - val_loss: 0.4124 - val_auc: 0.7703
# Epoch 2/100
# 592896/594000 [============================>.] - ETA: 0s - loss: 0.4088 - auc: 0.7692
# Epoch 00002: val_loss improved from 0.41242 to 0.40497, saving model to Weights-002--0.40497.hdf5
# 594000/594000 [==============================] - 13s 21us/sample - loss: 0.4088 - auc: 0.7693 - val_loss: 0.4050 - val_auc: 0.7731
# Epoch 3/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4037 - auc: 0.7779
# Epoch 00003: val_loss did not improve from 0.40497
# 594000/594000 [==============================] - 12s 21us/sample - loss: 0.4037 - auc: 0.7780 - val_loss: 0.4073 - val_auc: 0.7728
# Epoch 4/100
# 592896/594000 [============================>.] - ETA: 0s - loss: 0.4007 - auc: 0.7824
# Epoch 00004: val_loss did not improve from 0.40497
# 594000/594000 [==============================] - 12s 21us/sample - loss: 0.4007 - auc: 0.7824 - val_loss: 0.4070 - val_auc: 0.7716
# Epoch 5/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3958 - auc: 0.7897
# Epoch 00005: val_loss did not improve from 0.40497
# 594000/594000 [==============================] - 12s 21us/sample - loss: 0.3958 - auc: 0.7898 - val_loss: 0.4067 - val_auc: 0.7749
# Epoch 6/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3892 - auc: 0.7995
# Epoch 00006: val_loss did not improve from 0.40497
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.3892 - auc: 0.7995 - val_loss: 0.4156 - val_auc: 0.7637
# Epoch 7/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3802 - auc: 0.8122
# Epoch 00007: val_loss did not improve from 0.40497
# 594000/594000 [==============================] - 13s 21us/sample - loss: 0.3802 - auc: 0.8120 - val_loss: 0.4149 - val_auc: 0.7589
# Epoch 8/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3694 - auc: 0.8261
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00008: val_loss did not improve from 0.40497
# 594000/594000 [==============================] - 17s 28us/sample - loss: 0.3694 - auc: 0.8262 - val_loss: 0.4212 - val_auc: 0.7589
# Epoch 9/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3433 - auc: 0.8558
# Epoch 00009: val_loss did not improve from 0.40497
# 594000/594000 [==============================] - 20s 33us/sample - loss: 0.3433 - auc: 0.8559 - val_loss: 0.4442 - val_auc: 0.7418
# Epoch 10/100
# 592896/594000 [============================>.] - ETA: 0s - loss: 0.3299 - auc: 0.8694Restoring model weights from the end of the best epoch.
#
# Epoch 00010: val_loss did not improve from 0.40497
# 594000/594000 [==============================] - 19s 33us/sample - loss: 0.3299 - auc: 0.8694 - val_loss: 0.4512 - val_auc: 0.7378
# Epoch 00010: early stopping
# 0.7738544917513043
# Train on 594000 samples, validate on 6000 samples
# Epoch 1/100
# 592896/594000 [============================>.] - ETA: 0s - loss: 0.4621 - auc: 0.7078
# Epoch 00001: val_loss improved from inf to 0.41257, saving model to Weights-001--0.41257.hdf5
# 594000/594000 [==============================] - 16s 27us/sample - loss: 0.4620 - auc: 0.7080 - val_loss: 0.4126 - val_auc: 0.7695
# Epoch 2/100
# 591872/594000 [============================>.] - ETA: 0s - loss: 0.4085 - auc: 0.7698
# Epoch 00002: val_loss improved from 0.41257 to 0.40740, saving model to Weights-002--0.40740.hdf5
# 594000/594000 [==============================] - 13s 23us/sample - loss: 0.4085 - auc: 0.7697 - val_loss: 0.4074 - val_auc: 0.7735
# Epoch 3/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4035 - auc: 0.7777
# Epoch 00003: val_loss improved from 0.40740 to 0.40709, saving model to Weights-003--0.40709.hdf5
# 594000/594000 [==============================] - 15s 26us/sample - loss: 0.4035 - auc: 0.7778 - val_loss: 0.4071 - val_auc: 0.7714
# Epoch 4/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4003 - auc: 0.7830
# Epoch 00004: val_loss did not improve from 0.40709
# 594000/594000 [==============================] - 18s 30us/sample - loss: 0.4003 - auc: 0.7829 - val_loss: 0.4081 - val_auc: 0.7714
# Epoch 5/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3954 - auc: 0.7901
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00005: val_loss did not improve from 0.40709
# 594000/594000 [==============================] - 20s 34us/sample - loss: 0.3954 - auc: 0.7901 - val_loss: 0.4105 - val_auc: 0.7702
# Epoch 6/100
# 592896/594000 [============================>.] - ETA: 0s - loss: 0.3812 - auc: 0.8103
# Epoch 00006: val_loss did not improve from 0.40709
# 594000/594000 [==============================] - 20s 33us/sample - loss: 0.3811 - auc: 0.8104 - val_loss: 0.4143 - val_auc: 0.7647
# Epoch 7/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3705 - auc: 0.8245Restoring model weights from the end of the best epoch.
#
# Epoch 00007: val_loss did not improve from 0.40709
# 594000/594000 [==============================] - 20s 34us/sample - loss: 0.3705 - auc: 0.8244 - val_loss: 0.4185 - val_auc: 0.7559
# Epoch 00007: early stopping
# 0.773037887656588
# Train on 594000 samples, validate on 6000 samples
# Epoch 1/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4623 - auc: 0.7079
# Epoch 00001: val_loss improved from inf to 0.41223, saving model to Weights-001--0.41223.hdf5
# 594000/594000 [==============================] - 16s 26us/sample - loss: 0.4623 - auc: 0.7078 - val_loss: 0.4122 - val_auc: 0.7752
# Epoch 2/100
# 592896/594000 [============================>.] - ETA: 0s - loss: 0.4086 - auc: 0.7695
# Epoch 00002: val_loss improved from 0.41223 to 0.40174, saving model to Weights-002--0.40174.hdf5
# 594000/594000 [==============================] - 16s 27us/sample - loss: 0.4085 - auc: 0.7695 - val_loss: 0.4017 - val_auc: 0.7784
# Epoch 3/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4038 - auc: 0.7777
# Epoch 00003: val_loss improved from 0.40174 to 0.40165, saving model to Weights-003--0.40165.hdf5
# 594000/594000 [==============================] - 17s 29us/sample - loss: 0.4038 - auc: 0.7777 - val_loss: 0.4016 - val_auc: 0.7801
# Epoch 4/100
# 592896/594000 [============================>.] - ETA: 0s - loss: 0.3997 - auc: 0.7838
# Epoch 00004: val_loss did not improve from 0.40165
# 594000/594000 [==============================] - 20s 34us/sample - loss: 0.3997 - auc: 0.7837 - val_loss: 0.4065 - val_auc: 0.7750
# Epoch 5/100
# 592896/594000 [============================>.] - ETA: 0s - loss: 0.3954 - auc: 0.7901
# Epoch 00005: val_loss did not improve from 0.40165
# 594000/594000 [==============================] - 19s 32us/sample - loss: 0.3955 - auc: 0.7899 - val_loss: 0.4076 - val_auc: 0.7693
# Epoch 6/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3887 - auc: 0.8001
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00006: val_loss did not improve from 0.40165
# 594000/594000 [==============================] - 19s 32us/sample - loss: 0.3887 - auc: 0.8001 - val_loss: 0.4129 - val_auc: 0.7652
# Epoch 7/100
# 591872/594000 [============================>.] - ETA: 0s - loss: 0.3700 - auc: 0.8251
# Epoch 00007: val_loss did not improve from 0.40165
# 594000/594000 [==============================] - 13s 23us/sample - loss: 0.3700 - auc: 0.8251 - val_loss: 0.4251 - val_auc: 0.7516
# Epoch 8/100
# 591872/594000 [============================>.] - ETA: 0s - loss: 0.3574 - auc: 0.8405Restoring model weights from the end of the best epoch.
#
# Epoch 00008: val_loss did not improve from 0.40165
# 594000/594000 [==============================] - 14s 24us/sample - loss: 0.3574 - auc: 0.8404 - val_loss: 0.4376 - val_auc: 0.7376
# Epoch 00008: early stopping
# 0.7794402608170165
# Train on 594000 samples, validate on 6000 samples
# Epoch 1/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4637 - auc: 0.7076
# Epoch 00001: val_loss improved from inf to 0.40671, saving model to Weights-001--0.40671.hdf5
# 594000/594000 [==============================] - 14s 24us/sample - loss: 0.4637 - auc: 0.7076 - val_loss: 0.4067 - val_auc: 0.7737
# Epoch 2/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4085 - auc: 0.7699
# Epoch 00002: val_loss improved from 0.40671 to 0.40295, saving model to Weights-002--0.40295.hdf5
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.4085 - auc: 0.7700 - val_loss: 0.4029 - val_auc: 0.7778
# Epoch 3/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.4036 - auc: 0.7780
# Epoch 00003: val_loss improved from 0.40295 to 0.40190, saving model to Weights-003--0.40190.hdf5
# 594000/594000 [==============================] - 12s 20us/sample - loss: 0.4036 - auc: 0.7780 - val_loss: 0.4019 - val_auc: 0.7796
# Epoch 4/100
# 592896/594000 [============================>.] - ETA: 0s - loss: 0.4001 - auc: 0.7831
# Epoch 00004: val_loss did not improve from 0.40190
# 594000/594000 [==============================] - 12s 21us/sample - loss: 0.4001 - auc: 0.7832 - val_loss: 0.4045 - val_auc: 0.7761
# Epoch 5/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3957 - auc: 0.7899
# Epoch 00005: val_loss did not improve from 0.40190
# 594000/594000 [==============================] - 12s 21us/sample - loss: 0.3957 - auc: 0.7900 - val_loss: 0.4069 - val_auc: 0.7749
# Epoch 6/100
# 591872/594000 [============================>.] - ETA: 0s - loss: 0.3891 - auc: 0.7994
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00006: val_loss did not improve from 0.40190
# 594000/594000 [==============================] - 12s 21us/sample - loss: 0.3891 - auc: 0.7992 - val_loss: 0.4070 - val_auc: 0.7716
# Epoch 7/100
# 593920/594000 [============================>.] - ETA: 0s - loss: 0.3703 - auc: 0.8247
# Epoch 00007: val_loss did not improve from 0.40190
# 594000/594000 [==============================] - 12s 21us/sample - loss: 0.3703 - auc: 0.8247 - val_loss: 0.4199 - val_auc: 0.7606
# Epoch 8/100
# 592896/594000 [============================>.] - ETA: 0s - loss: 0.3578 - auc: 0.8396Restoring model weights from the end of the best epoch.
#
# Epoch 00008: val_loss did not improve from 0.40190
# 594000/594000 [==============================] - 12s 21us/sample - loss: 0.3578 - auc: 0.8394 - val_loss: 0.4246 - val_auc: 0.7527
# Epoch 00008: early stopping
# 0.7793767643976307

# %%
print("Overall AUC={}".format(metrics.roc_auc_score(train.target.values, oof_preds)))
# Out:
# Overall AUC=0.7772291232066377

# %%
test_preds /= NSPLIT
test_ids = test.id.values
print("Saving submission file")
submission = pd.DataFrame.from_dict({
    'id': test_ids,
    'target': test_preds
})
submission.to_csv("./input/submission.csv", index=False)
# Out:
# Saving submission file
